# %%
import torch
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from VIS_SWIR_helper import Hypercube

# %%
data_path="/Volumes/KINGSTON/Headwall_data/Delamination_with_crack/Dry_sample/data_vnir.csv"

# %%
hyper_photos=Hypercube()

# %%
data_vnir=hyper_photos.reshape_3d(data_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data_vnir=hyper_photos.reshape_3d(data_path)
#
# NameError: name 'data_path' is not defined

# %%
data_vnir.size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data_vnir.size()
#
# NameError: name 'data_vnir' is not defined
